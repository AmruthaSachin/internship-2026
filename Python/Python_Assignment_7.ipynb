# %% [markdown]
# Classes

# %% [markdown]
# 1) Write a python class to convert an integer into a roman numeral and viceversa

# %%
class Conversion():
   def romanToInt(self,s):
     romanmap = {'I':1, 'V':5, 'X':10, 'L':50, 'C':100,'D':500,'M':1000}
     res= 0
     i =0

     while i< len(s):
      if i+1<len(s) and romanmap[s[i]] < romanmap[s[i+1]]:
            res += (romanmap[s[i+1]] - romanmap[s[i]])
            i+=1
      else:
            res += romanmap[s[i]]

      i+=1

      return res


   def intToRoman(self,num):
     values = [1000,900,500,400,100,90,50,40,10,9,5,4,1]
     symbols = ["M","CM","D","CD","C","XC","L","XL","X","IX","V","IV","I"]
     res = ""

     for i in range(len(values)):
       while num >= values[i]:
         res += symbols[i]
         num -= values[i]

     return res




s = "MMIV"
obj = Conversion()
print(f"Roman to Integer of {s}: ",obj.romanToInt(s))

num = 2026
print(f"Integer to Roman of {num} is: ",obj.intToRoman(num))
# Out:
# Roman to Integer of MMIV:  1000
# Integer to Roman of 2026 is:  MMXXVI

# %% [markdown]
# 2) Write a Python class to find validity of a string of parentheses, '(', ')', '{', '}', '[' and ']. These brackets must be close in the correct order, for example "()" and "()[]{}" are valid but "[)", "({[)]" and "{{{" are invalid.

# %%
def parenthesis(string):
    pairs = {
        ')': '(',
        '}': '{',
        ']': '['
    }

    stack = []

    for s in string:

        if s in "({[":
            stack.append(s)

        elif s in ")}]":

            if not stack or stack[-1] != pairs[s]:
                return False

            stack.pop()

    return not stack


string = "[({)]"
print(parenthesis(string))
# Out:
# False

# %% [markdown]
# 3) Write a Python class to get all possible unique subsets from a set of distinct integers Input : [4, 5, 6] Output : [[], [6], [5], [5, 6], [4], [4, 6], [4, 5], [4, 5, 6]]

# %%
class FindSubsets():
   def subsets(self,arr):
    n = len(arr)
    for i in range(1 << n):
       subset = []
       for j in range(n):
         if i & (1 << j):
           subset.append(arr[j])
       print(subset)


arr = [4, 5, 6]
obj = FindSubsets()
obj.subsets(arr)
# Out:
# []
# [4]
# [5]
# [4, 5]
# [6]
# [4, 6]
# [5, 6]
# [4, 5, 6]

# %% [markdown]
# 4) Write a Python class to find a pair of elements (indices of the two numbers) from a given array whose sum equals a specific target number. Note: There will be one solution for each input and do not use the same element twice. Input: numbers= [90, 20,10,40,50,60,70], target=50 Output: 3, 4

# %%
class PairOfElements:
  def pairOfElements(self,numbers,target):
     prefixSum = {}
     for i,num in enumerate(numbers):
       complement = target - num
       if complement in prefixSum:
         return [prefixSum[complement]+1,i+1]
       prefixSum[num] = i
     return []



numbers = [90, 20,10,40,50,60,70]
target = 50
obj = PairOfElements()
result = obj.pairOfElements(numbers, target)
print(result)
# Out:
# [3, 4]

# %% [markdown]
# 5) Write a Python class to find the three elements that sum to zero from a set of n real numbers. Input array : [-25, -10, -7, -3, 2, 4, 8, 10] Output : [[-10, 2, 8], [-7, -3, 10]]

# %%
class ThreeSum:
    def find_triplets(self, arr):
        result = []

        n = len(arr)

        for i in range(n):
            for j in range(i + 1, n):
                for k in range(j + 1, n):

                    if arr[i] + arr[j] + arr[k] == 0:
                        result.append([arr[i], arr[j], arr[k]])

        return result


arr = [-25, -10, -7, -3, 2, 4, 8, 10]

obj = ThreeSum()
print(obj.find_triplets(arr))
# Out:
# [[-10, 2, 8], [-7, -3, 10]]

# %% [markdown]
# 6) Write a Python class to implement pow(x, n)

# %%
class Power:
    def pow(self, x, n):
        return x ** n


obj = Power()

print(obj.pow(2, 3))
print(obj.pow(5, 2))
# Out:
# 8
# 25

# %% [markdown]
# 7) Write a Python class to reverse a string word by word.
#
#  Input string : 'hello .py' Expected Output : '.py hello'

# %%
class ReverseString():
  def reverse(self,string):
    words = string.split()
    reversed_words = words[::-1]
    reversed_string = " ".join(reversed_words)
    return reversed_string


string = "hello .py"
obj = ReverseString()
print(obj.reverse(string))
# Out:
# .py hello

# %% [markdown]
# 8) Write a python class which has 2 methods get_string and print_string. get_string takes a string from the user and print_string prints the string in reverse order

# %%
class StringOperations:

    def get_string(self):
        self.string = input("Enter a string: ")

    def print_string(self):
        print(self.string[::-1])


obj = StringOperations()

obj.get_string()
obj.print_string()
# Out:
# Enter a string: hi hello
# olleh ih

# %% [markdown]
# 9) Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle.

# %%
class Circle:

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius * self.radius

    def perimeter(self):
        return 2 * 3.14159 * self.radius


c = Circle(5)

print("Area =", c.area())
print("Perimeter =", c.perimeter())
# Out:
# Area = 78.53975
# Perimeter = 31.4159

# %% [markdown]
# 10) Write a Python program to get the class name of an instance in Python.

# %%
class Student:
    pass

obj = Student()

print(obj.__class__.__name__)
# Out:
# Student

# %% [markdown]
# Lambda

# %% [markdown]
# 1) Write a Python program to create a lambda function that adds 15 to a given number passed in as an argument, also create a lambda function that multiplies argument x with argument y and print the result.
#
#  Sample Output: 25 48

# %%
add = lambda x : x + 15
x = 25
print(f"{x} : {add(x)}")

multiply = lambda x,y : x*y
x = 12
y = 4
print(f"{x} : {multiply(x,y)}")
# Out:
# 25 : 40
# 12 : 48

# %% [markdown]
# 2) Write a Python program to sort a list of tuples using Lambda.
#
# Original list of tuples: [('English', 88), ('Science', 90), ('Maths', 97), ('Social sciences', 82)]
#
# Sorting the List of Tuples: [('Social sciences', 82), ('English', 88), ('Science', 90), ('Maths', 97)]

# %%
def sorting(arr):
  arr = sorted(arr,key = lambda x : x[1])
  return arr

arr = [('English', 88), ('Science', 90), ('Maths', 97), ('Social sciences', 82)]
print(sorting(arr))
# Out:
# [('Social sciences', 82), ('English', 88), ('Science', 90), ('Maths', 97)]

# %% [markdown]
#  3) Write a Python program to sort a list of dictionaries using Lambda.

# %%
def sort(arr):
    arr.sort(key = lambda x : x['color'])
    return arr

arr = [
        {'make': 'Nokia', 'model': 216, 'color': 'Black'},
        {'make': 'Mi Max', 'model': 2, 'color': 'Gold'},
        {'make': 'Samsung', 'model': 7, 'color': 'Blue'}
  ]

print(sort(arr))
# Out:
# [{'make': 'Nokia', 'model': 216, 'color': 'Black'}, {'make': 'Samsung', 'model': 7, 'color': 'Blue'}, {'make': 'Mi Max', 'model': 2, 'color': 'Gold'}]

# %% [markdown]
# 4) Write a Python program to find if a given string starts with a given character using Lambda.

# %%
s = input("Enter a string: ")
ch = input("Enter a character: ")

starts_with = lambda string, char: string.startswith(char)

if starts_with(s, ch):
    print("The string starts with the given character.")
else:
    print("The string does not start with the given character.")
# Out:
# Enter a string: hello
# Enter a character: h
# The string starts with the given character.

# %% [markdown]
# 5) Write a Python program to check whether a given string is number or not using Lambda.

# %%
def checkString(string):

  check = lambda string : string.isalnum()
  if check(string):
    return True
  return False

s = input("Enter a string: ")
res = checkString(s)
print(res)
# Out:
# Enter a string: 3456
# True

# %% [markdown]
# 6)  Write a Python program to find numbers divisible by nineteen or thirteen from a list of numbers using Lambda
#
# Orginal list: [19, 65, 57, 39, 152, 639, 121, 44, 90, 190]
#
# Numbers of the above list divisible by nineteen or thirteen: [19, 65, 57, 39, 152, 190]

# %%
def checkDivisiblity(arr):
  checkdiv = list(filter(lambda x : x % 19 == 0 or x % 13 == 0 , arr))
  return checkdiv

arr = [19, 65, 57, 39, 152, 639, 121, 44, 90, 190]
res = checkDivisiblity(arr)
print(res)
# Out:
# [19, 65, 57, 39, 152, 190]

# %% [markdown]
# 7) Write a Python program to sort a given matrix in ascending order according to the sum of its rows using lambda.
#
# Original Matrix: [[1, 2, 3], [2, 4, 5], [1, 1, 1]]
#
# Sort the said matrix in ascending order according to the sum of its rows [[1, 1, 1], [1, 2, 3], [2, 4, 5]]
#
#  Original Matrix: [[1, 2, 3], [-2, 4, -5], [1, -1, 1]]
#
# Sort the said matrix in ascending order according to the sum of its rows [[-2, 4, -5], [1, -1, 1], [1, 2, 3]]

# %%
def sortMatrix(arr):
  arr.sort(key = lambda x : sum(x))
  return arr

arr = [[1, 2, 3], [2, 4, 5], [1, 1, 1]]
print("Original Matrix: ",arr)
print(f"Sorted the said matrix in ascending order according to the sum of its rows: {sortMatrix(arr)}")
# Out:
# Original Matrix:  [[1, 2, 3], [2, 4, 5], [1, 1, 1]]
# Sorted the said matrix in ascending order according to the sum of its rows: [[1, 1, 1], [1, 2, 3], [2, 4, 5]]

# %% [markdown]
# 8) Write a Python program to check whether a given string contains a capital letter, a lower case letter, a number and a minimum length using lambda.
#
# Minimum length : 10 input string: PaceWisd0m o/p: valid string

# %%
def checkstring8(string):
  check = lambda string : len(string) >= 10 and any(char.isupper() for char in string) and any(char.islower() for char in string) and any(char.isdigit() for char in string)
  if check(string):
    print("Valid string")
  else:
    print("Invalid string")

s = "PaceWisd0m"
checkstring8(s)
# Out:
# Valid string

# %% [markdown]
# 9) Write a Python program to find the elements of a given list of strings that contain specific substring using lambda.
#
# Original list: ['red', 'black', 'white', 'green', 'orange']
#
# Substring to search: ack Elements of the said list that contain specific substring: ['black']
#
# Substring to search: abc Elements of the said list that contain specific substring: []

# %%
def searchSubstring(strings):
  substring = input("Enter a substring: ")
  result = list(filter(lambda x : substring in x,strings))
  return result

strings = ['red', 'black', 'white', 'green', 'orange']
res = searchSubstring(strings)
print(res)
# Out:
# Enter a substring: ack
# ['black']

# %% [markdown]
# 10) Write a Python program to sort a given mixed list of integers and strings using lambda. Numbers must be sorted before strings.
#
# Original list: [19, 'red', 12, 'green', 'blue', 10, 'white', 'green', 1]
#
# Sort the said mixed list of integers and strings: [1, 10, 12, 19, 'blue', 'green', 'green', 'red', 'white']

# %%
mixed_list = [19, 'red', 12, 'green', 'blue', 10, 'white', 'green', 1]
result = sorted(mixed_list, key=lambda x: (isinstance(x, str), x))
print(result)
# Out:
# [1, 10, 12, 19, 'blue', 'green', 'green', 'red', 'white']
